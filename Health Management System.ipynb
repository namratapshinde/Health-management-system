# %%
import datetime

def getdate():
    return (datetime.datetime.now())

x = int(input("Press the number you have to following name:\n(1) For Namrata\n(2) For Aakanksha\n(3) For Darshan\n"))
v1 = ["Namrata", "Aakanksha", "Darshan"]
v2 = ["123", "456", "789"]

username = input("Enter a name: ")
password = input("Enter a pass: ")

if x == 1:
    if v1[0] == username and v2[0] == password:
        print("Welcome")
        s = str(input("What do you want Namrata food list or exercise list??\n"))
        if s.capitalize() == "Food":
            y = str(input("What do you want to write or read??\n"))
            if y.capitalize() == "Write":
                print("[", getdate(), "]")
                f = open("Namrata_food.txt", "a")
                print("What you eat:")
                d = input()
                f.write(f"{getdate()}: {d}\n")
                print("You have successfully entered.")
                f.close()
            elif y.capitalize() == "Read":
                print("[", getdate(), "]")
                f = open("Namrata_food.txt")
                r = f.read()
                print(r)
                f.close()
            else:
                print("Invalid, please try again.")
        elif s.capitalize() == "Exercise":
            z = str(input("What do you want to write or read??\n"))
            if z.capitalize() == "Write":
                print("[", getdate(), "]")
                f = open("Namrata_exercise.txt", "a")
                d = input("What do you do today:")
                f.write(f"{getdate()}: {d}\n")
                print("You have successfully entered.")
                f.close()
            elif z.capitalize() == "Read":
                print("[", getdate(), "]")
                f = open("Namrata_exercise.txt")
                r = f.read()
                print(r)
                f.close()
            else:
                print("Invalid, please try again.")
        else:
            print("Invalid, please try again.")
    else:
        print("Invalid credentials.")

elif x == 2:
    if v1[1] == username and v2[1] == password:
        print("Welcome")
        s = str(input("What do you want Aakanksha food list or exercise list??\n"))
        if s.capitalize() == "Food":
            y = str(input("What do you want to write or read??\n"))
            if y.capitalize() == "Write":
                print("[", getdate(), "]")
                f = open("Aakanksha_food.txt", "a")
                print("What you eat:")
                d = input()
                f.write(f"{getdate()}: {d}\n")
                print("You have successfully entered.")
                f.close()
            elif y.capitalize() == "Read":
                print("[", getdate(), "]")
                f = open("Aakanksha_food.txt")
                r = f.read()
                print(r)
                f.close()
            else:
                print("Invalid, please try again.")
        elif s.capitalize() == "Exercise":
            z = str(input("What do you want to write or read??\n"))
            if z.capitalize() == "Write":
                print("[", getdate(), "]")
                f = open("Aakanksha_exercise.txt", "a")
                d = input("What do you do today:")
                f.write(f"{getdate()}: {d}\n")
                print("You have successfully entered.")
                f.close()
            elif z.capitalize() == "Read":
                print("[", getdate(), "]")
                f = open("Aakanksha_exercise.txt")
                r = f.read()
                print(r)
                f.close()
            else:
                print("Invalid, please try again.")
        else:
            print("Invalid, please try again.")
    else:
        print("Invalid")

elif x == 3:
    if v1[2] == username and v2[2] == password:
        print("Welcome")
        s = str(input("What do you want Darshan food list or exercise list??\n"))
        if s.capitalize() == "Food":
            y = str(input("What do you want to write or read??\n"))
            if y.capitalize() == "Write":
                print("[", getdate(), "]")
                f = open("Darshan_food.txt", "a")
                print("What you eat:")
                d = input()
                f.write(f"{getdate()}: {d}\n")
                print("You have successfully entered.")
                f.close()
            elif y.capitalize() == "Read":
                print("[", getdate(), "]")
                f = open("Darshan_food.txt")
                r = f.read()
                print(r)
                f.close()
            else:
                print("Invalid, please try again.")
        elif s.capitalize() == "Exercise":
            z = str(input("What do you want to write or read??\n"))
            if z.capitalize() == "Write":
                print("[", getdate(), "]")
                f = open("Darshan_exercise.txt", "a")
                d = input("What do you do today:")
                f.write(f"{getdate()}: {d}\n")
                print("You have successfully entered.")
                f.close()
            elif z.capitalize() == "Read":
                print("[", getdate(), "]")
                f = open("Darshan_exercise.txt")
                r = f.read()
                print(r)
                f.close()
            else:
                print("Invalid, please try again.")
        else:
            print("Invalid, please try again.")
    else:
        print("Invalid")
else:
    print("Invalid input. Please press the correct number.")

print("THANKS FOR USING:\nBY @SHINDE NAMRATA PRAKASH")
